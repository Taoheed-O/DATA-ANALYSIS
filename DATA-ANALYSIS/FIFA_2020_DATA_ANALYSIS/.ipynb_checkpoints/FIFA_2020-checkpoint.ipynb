# %%
# Importing necessary libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import warnings
import re
from io import BytesIO
from PIL import Image
from bs4 import BeautifulSoup as bs
warnings.filterwarnings("ignore")

# %%
# Loading the fifa dataset
df = pd.read_csv('players_20.csv')

# Making a copy of the dataset
df_copy = df.copy()
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
# Extracting the image URL fom the player_url column by using RegularExpression
df['image_url'] = df['player_url'].str.extract(r'(https:\/\/sofifa.com\/player\/[0-9]+\/[a-zA-Z-]+\/)')
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   ldm   cdm  \
# 0        170         72   Argentina         FC Barcelona  ...  66+2  66+2
# 1        187         83    Portugal             Juventus  ...  61+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  61+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  63+3  63+3
#
#     rdm   rwb    lb   lcb    cb   rcb    rb  \
# 0  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
#                                            image_url
# 0     https://sofifa.com/player/158023/lionel-messi/
# 1  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2  https://sofifa.com/player/190871/neymar-da-sil...
# 3        https://sofifa.com/player/200389/jan-oblak/
# 4      https://sofifa.com/player/183277/eden-hazard/
#
# [5 rows x 105 columns]

# %%
df[df['long_name'] == 'Eden Hazard']
# Out:
#    sofifa_id                                         player_url short_name  \
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  E. Hazard
#
#      long_name  age         dob  height_cm  weight_kg nationality  \
# 4  Eden Hazard   28  1991-01-07        175         74     Belgium
#
#           club  ...   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb  \
# 4  Real Madrid  ...  63+3  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
#                                        image_url
# 4  https://sofifa.com/player/183277/eden-hazard/
#
# [1 rows x 105 columns]

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# std        6.139669  5.585481e+06   21351.714095                  0.378861
# min       49.000000  0.000000e+00       0.000000                  1.000000
# 25%       67.000000  3.250000e+05    1000.000000                  1.000000
# 50%       71.000000  7.000000e+05    3000.000000                  1.000000
# 75%       75.000000  2.100000e+06    8000.000000                  1.000000
# max       95.000000  1.055000e+08  565000.000000                  5.000000
#
#           weak_foot  ...  mentality_penalties  mentality_composure  \
# count  18278.000000  ...         18278.000000         18278.000000
# mean       2.944250  ...            48.383357            58.528778
# std        0.664656  ...            15.708099            11.880840
# min        1.000000  ...             7.000000            12.000000
# 25%        3.000000  ...            39.000000            51.000000
# 50%        3.000000  ...            49.000000            60.000000
# 75%        3.000000  ...            60.000000            67.000000
# max        5.000000  ...            92.000000            96.000000
#
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# count       18278.000000               18278.000000              18278.000000
# mean           46.848889                  47.640333                 45.606631
# std            20.091287                  21.585641                 21.217734
# min             1.000000                   5.000000                  3.000000
# 25%            29.000000                  27.000000                 24.000000
# 50%            52.000000                  55.000000                 52.000000
# 75%            64.000000                  66.000000                 64.000000
# max            94.000000                  92.000000                 90.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        18278.000000          18278.000000         18278.000000
# mean            16.572765             16.354853            16.212934
# std             17.738069             16.996925            16.613665
# min              1.000000              1.000000             1.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             90.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes
# count             18278.000000          18278.000000
# mean                 16.368038             16.709924
# std                  17.136497             18.038125
# min                   1.000000              1.000000
# 25%                   8.000000              8.000000
# 50%                  11.000000             11.000000
# 75%                  14.000000             14.000000
# max                  91.000000             92.000000
#
# [8 rows x 61 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 105 entries, sofifa_id to image_url
# dtypes: float64(16), int64(45), object(44)
# memory usage: 14.6+ MB

# %%
# Getting the columns of the data
columns = df.columns
columns = list(columns)
columns
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'image_url']

# %%
# Grouping the dataframe by countries
nations = list(df['nationality'].unique())
nations
nation_count_dic = {}
nation_dic = {}
for nation in nations:
    nation_dic[nation] = df[df['nationality'] == nation]
   

# Getting the cout list of players for each countries     
for nation in nations:
    counts = len(nation_dic[nation])
    nation_count_dic[nation] = counts

nation_count_dic
# Out:
# {'Argentina': 886,
#  'Portugal': 344,
#  'Brazil': 824,
#  'Slovenia': 61,
#  'Belgium': 268,
#  'Germany': 1216,
#  'Netherlands': 416,
#  'Croatia': 126,
#  'Egypt': 30,
#  'France': 984,
#  'Senegal': 127,
#  'England': 1667,
#  'Spain': 1035,
#  'Italy': 732,
#  'Uruguay': 164,
#  'Poland': 324,
#  'Denmark': 345,
#  'Gabon': 16,
#  'Korea Republic': 322,
#  'Costa Rica': 30,
#  'Slovakia': 54,
#  'Bosnia Herzegovina': 66,
#  'Serbia': 139,
#  'Scotland': 277,
#  'Hungary': 35,
#  'Switzerland': 229,
#  'Greece': 96,
#  'Austria': 319,
#  'Morocco': 94,
#  'Sweden': 358,
#  'Wales': 117,
#  'Colombia': 591,
#  'Czech Republic': 102,
#  'Chile': 370,
#  'Algeria': 50,
#  'Ivory Coast': 105,
#  'Togo': 13,
#  'Norway': 350,
#  'Mexico': 340,
#  'Iceland': 46,
#  'Finland': 72,
#  'Jamaica': 29,
#  'Albania': 43,
#  'Guinea': 35,
#  'Cameroon': 78,
#  'Ghana': 130,
#  'Montenegro': 33,
#  'Ukraine': 69,
#  'Russia': 81,
#  'DR Congo': 54,
#  'Central African Rep.': 4,
#  'Venezuela': 66,
#  'Nigeria': 126,
#  'Armenia': 8,
#  'Israel': 16,
#  'Ecuador': 53,
#  'Paraguay': 80,
#  'Australia': 196,
#  'Turkey': 294,
#  'Romania': 287,
#  'Japan': 453,
#  'Mali': 55,
#  'United States': 347,
#  'Kosovo': 40,
#  'Dominican Republic': 4,
#  'Tanzania': 4,
#  'China PR': 373,
#  'Northern Ireland': 81,
#  'Republic of Ireland': 348,
#  'Tunisia': 35,
#  'Cape Verde': 20,
#  'FYR Macedonia': 20,
#  'Burkina Faso': 16,
#  'Kenya': 7,
#  'Angola': 16,
#  'South Africa': 72,
#  'Peru': 35,
#  'Syria': 4,
#  'Gambia': 22,
#  'New Zealand': 35,
#  'Equatorial Guinea': 6,
#  'Zimbabwe': 12,
#  'Georgia': 25,
#  'Canada': 61,
#  'Estonia': 6,
#  'Benin': 15,
#  'Bulgaria': 41,
#  'Mozambique': 4,
#  'Honduras': 13,
#  'Guinea Bissau': 21,
#  'Iran': 15,
#  'Philippines': 2,
#  'Cyprus': 11,
#  'Madagascar': 8,
#  'Uzbekistan': 3,
#  'Moldova': 12,
#  'Cuba': 4,
#  'Sierra Leone': 10,
#  'Curacao': 16,
#  'Zambia': 10,
#  'Congo': 18,
#  'Bolivia': 23,
#  'Comoros': 9,
#  'Iraq': 5,
#  'Chad': 1,
#  'Lithuania': 10,
#  'Saudi Arabia': 310,
#  'Panama': 12,
#  'Libya': 4,
#  'Bahrain': 1,
#  'St Kitts Nevis': 4,
#  'New Caledonia': 2,
#  'Luxembourg': 9,
#  'Trinidad & Tobago': 6,
#  'Thailand': 4,
#  'United Arab Emirates': 22,
#  'Eritrea': 1,
#  'Korea DPR': 4,
#  'El Salvador': 4,
#  'Azerbaijan': 6,
#  'Latvia': 6,
#  'Montserrat': 3,
#  'Puerto Rico': 1,
#  'Bermuda': 3,
#  'São Tomé & Príncipe': 1,
#  'Antigua & Barbuda': 7,
#  'Burundi': 4,
#  'Kazakhstan': 2,
#  'Liberia': 1,
#  'Guyana': 4,
#  'Haiti': 7,
#  'Jordan': 1,
#  'Faroe Islands': 5,
#  'Mauritania': 5,
#  'Namibia': 2,
#  'Rwanda': 2,
#  'Uganda': 3,
#  'Hong Kong': 1,
#  'Chinese Taipei': 1,
#  'Belize': 1,
#  'Palestine': 4,
#  'Mauritius': 1,
#  'Guam': 1,
#  'Suriname': 2,
#  'Lebanon': 3,
#  'Guatemala': 2,
#  'Sudan': 3,
#  'Liechtenstein': 2,
#  'Grenada': 2,
#  'St Lucia': 1,
#  'Afghanistan': 2,
#  'Ethiopia': 1,
#  'Barbados': 1,
#  'India': 23,
#  'Malta': 2,
#  'Niger': 3,
#  'Vietnam': 1,
#  'Malawi': 1,
#  'Gibraltar': 1,
#  'Macau': 1,
#  'South Sudan': 1,
#  'Indonesia': 1}

# %%
# Grouping the dataframe by Clubs

clubs = list(df['club'].unique())
clubs
club_count_list = {}
club_dic = {}
for club in clubs:
    club_dic[club] = df[df['club'] == club]
club_dic['Chelsea']


# Getting the count list of players for each countries     
for club in clubs:
    counts = len(club_dic[club])
    club_count_list[club] = counts
club_count_list
# Out:
# {'FC Barcelona': 33,
#  'Juventus': 33,
#  'Paris Saint-Germain': 33,
#  'Atlético Madrid': 33,
#  'Real Madrid': 33,
#  'Manchester City': 33,
#  'Liverpool': 33,
#  'Napoli': 31,
#  'Tottenham Hotspur': 33,
#  'Manchester United': 33,
#  'Chelsea': 33,
#  'FC Bayern München': 23,
#  'Inter': 30,
#  'Borussia Dortmund': 31,
#  'Arsenal': 33,
#  'Valencia CF': 33,
#  'Lazio': 33,
#  'Milan': 29,
#  'Sporting CP': 30,
#  'Olympique Lyonnais': 29,
#  'RB Leipzig': 33,
#  'Ajax': 30,
#  'LA Galaxy': 27,
#  'Atalanta': 28,
#  'RC Celta': 33,
#  'Bayer 04 Leverkusen': 25,
#  'Real Betis': 31,
#  'FC Porto': 30,
#  'SV Werder Bremen': 32,
#  'West Ham United': 33,
#  'Wolverhampton Wanderers': 33,
#  'AS Saint-Étienne': 32,
#  'Torino': 29,
#  'Dalian YiFang FC': 28,
#  'Borussia Mönchengladbach': 33,
#  'Roma': 31,
#  'Guangzhou Evergrande Taobao FC': 28,
#  'SL Benfica': 30,
#  'Medipol Başakşehir FK': 30,
#  'Everton': 33,
#  'VfL Wolfsburg': 33,
#  'Crystal Palace': 33,
#  'Getafe CF': 30,
#  'Shanghai SIPG FC': 28,
#  'Eintracht Frankfurt': 33,
#  'Olympique de Marseille': 27,
#  'Hertha BSC': 33,
#  'RSC Anderlecht': 28,
#  'Villarreal CF': 32,
#  'Sampdoria': 32,
#  'Leicester City': 33,
#  'AS Monaco': 33,
#  'Jiangsu Suning FC': 25,
#  'Los Angeles FC': 23,
#  'Cagliari': 31,
#  'Sevilla FC': 33,
#  'Fenerbahçe SK': 29,
#  'Real Sociedad': 30,
#  'TSG 1899 Hoffenheim': 30,
#  'Atlético Mineiro': 20,
#  'Grêmio': 20,
#  'PSV': 30,
#  'Athletic Club de Bilbao': 33,
#  'Deportivo Alavés': 33,
#  'Boca Juniors': 28,
#  'Lokomotiv Moscow': 28,
#  'Al Nassr': 30,
#  'Brescia': 28,
#  'Shakhtar Donetsk': 28,
#  'Shanghai Greenland Shenhua FC': 28,
#  'PFC CSKA Moscow': 24,
#  'Beijing Sinobo Guoan FC': 26,
#  'Levante UD': 32,
#  'Cruzeiro': 20,
#  'Uruguay': 23,
#  'Montpellier HSC': 27,
#  'Atlanta United': 30,
#  'Watford': 33,
#  '1. FC Köln': 31,
#  'Bournemouth': 33,
#  'Beşiktaş JK': 30,
#  'Real Valladolid CF': 33,
#  'Racing Club': 28,
#  'Al Hilal': 29,
#  'Guangzhou R&F FC': 27,
#  'Sassuolo': 28,
#  'FC Girondins de Bordeaux': 32,
#  'LOSC Lille': 31,
#  'Galatasaray SK': 30,
#  'Chicago Fire': 27,
#  'Fluminense': 20,
#  'Ecuador': 23,
#  'RCD Espanyol': 30,
#  'Dinamo Zagreb': 28,
#  'FC Nantes': 33,
#  'River Plate': 28,
#  'OGC Nice': 29,
#  'Newcastle United': 33,
#  'Brighton & Hove Albion': 33,
#  'Club Brugge KV': 27,
#  'FC Schalke 04': 30,
#  'SD Eibar': 28,
#  'DC United': 27,
#  'Orlando City SC': 28,
#  'Hebei China Fortune FC': 26,
#  'Tigres U.A.N.L.': 26,
#  'Aston Villa': 33,
#  'Montreal Impact': 26,
#  'Olympiacos CFP': 28,
#  'Norwich City': 33,
#  'Feyenoord': 30,
#  'Toronto FC': 30,
#  'KRC Genk': 28,
#  'Fiorentina': 30,
#  'Spartak Moscow': 28,
#  'Dynamo Kyiv': 28,
#  'SK Slavia Praha': 25,
#  'Southampton': 33,
#  'Burnley': 33,
#  'SC Braga': 28,
#  'Russia': 10,
#  'RC Strasbourg Alsace': 28,
#  'Wuhan Zall': 28,
#  'Vissel Kobe': 29,
#  'Portland Timbers': 27,
#  'Genoa': 32,
#  'Beijing Renhe FC': 28,
#  'Toulouse Football Club': 29,
#  'Girona FC': 25,
#  'Real Zaragoza': 29,
#  'CD Leganés': 33,
#  'Shenzhen FC': 27,
#  'Internacional': 20,
#  'CSA - AL': 20,
#  'Santos': 20,
#  '1. FSV Mainz 05': 33,
#  'Stoke City': 30,
#  'Udinese': 33,
#  'Colombia': 1,
#  'Angers SCO': 31,
#  'FC Augsburg': 33,
#  'Netherlands': 1,
#  'Fulham': 30,
#  'FC København': 27,
#  'KAA Gent': 28,
#  'SC Freiburg': 31,
#  'Stade Rennais FC': 23,
#  'Club América': 22,
#  'Trabzonspor': 30,
#  'BSC Young Boys': 27,
#  'Helsingborgs IF': 27,
#  'Kaizer Chiefs': 28,
#  'Parma': 33,
#  'Mexico': 1,
#  'Royal Antwerp FC': 28,
#  'Tianjin TEDA FC': 28,
#  'Hannover 96': 28,
#  'Tianjin Quanjian FC': 27,
#  'Al Ahli': 30,
#  'Bologna': 31,
#  'VfB Stuttgart': 30,
#  'Seattle Sounders FC': 27,
#  'Godoy Cruz': 28,
#  'Sparta Praha': 28,
#  'Independiente Medellín': 28,
#  'Sivasspor': 26,
#  'Independiente': 28,
#  'Nîmes Olympique': 23,
#  'Club Tijuana': 28,
#  'SPAL': 27,
#  'Monterrey': 29,
#  'CD Tondela': 27,
#  'Fortuna Düsseldorf': 33,
#  'Vitória Guimarães': 30,
#  'AZ Alkmaar': 27,
#  'Atlético de San Luis': 27,
#  'PAOK': 27,
#  'Nagoya Grampus': 29,
#  'Club Atlético Banfield': 28,
#  'Shandong Luneng TaiShan FC': 28,
#  'New York Red Bulls': 29,
#  'FC Red Bull Salzburg': 27,
#  'Sweden': 3,
#  'Amiens SC': 32,
#  'Hellas Verona': 33,
#  'Cruz Azul': 28,
#  'Gençlerbirliği SK': 24,
#  '1. FC Union Berlin': 33,
#  'Standard de Liège': 28,
#  'Chongqing Dangdai Lifan FC SWM Team': 25,
#  'New England Revolution': 26,
#  'Club Atlético Colón': 28,
#  'Celtic': 28,
#  'Club Atlas': 28,
#  'Botafogo': 20,
#  'En Avant de Guingamp': 30,
#  'West Bromwich Albion': 30,
#  'Pachuca': 25,
#  'AEK Athens': 28,
#  'Portimonense SC': 30,
#  'Real Salt Lake': 29,
#  'FC Utrecht': 27,
#  'Sheffield United': 33,
#  "Newell's Old Boys": 28,
#  'Club Atlético Talleres': 28,
#  'Philadelphia Union': 27,
#  'Rosenborg BK': 27,
#  'FC Basel 1893': 27,
#  'Brentford': 30,
#  'Club León': 28,
#  'Unión de Santa Fe': 25,
#  'Deportivo de La Coruña': 24,
#  'Rangers FC': 28,
#  'Turkey': 1,
#  'Atiker Konyaspor': 27,
#  'Granada CF': 27,
#  'Perth Glory': 23,
#  'Club Atlético Lanús': 28,
#  'Hamburger SV': 30,
#  'Al Ittihad': 30,
#  'Santos Laguna': 25,
#  'Western United FC': 20,
#  'Columbus Crew SC': 28,
#  'Deportivo Toluca': 25,
#  'Cardiff City': 30,
#  'CA Osasuna': 30,
#  'Swansea City': 30,
#  'Melbourne Victory': 19,
#  'Leeds United': 30,
#  'Göztepe SK': 28,
#  'Hungary': 12,
#  'New York City FC': 24,
#  'Bulgaria': 20,
#  'Kayserispor': 29,
#  'Minnesota United FC': 24,
#  'Guadalajara': 27,
#  'FC Groningen': 27,
#  'Paraguay': 9,
#  'Junior FC': 28,
#  'Al Taawoun': 26,
#  'Huddersfield Town': 30,
#  'Ettifaq FC': 27,
#  'Stade de Reims': 26,
#  'Rayo Vallecano': 30,
#  'San Lorenzo de Almagro': 28,
#  'Bahia': 20,
#  'Atlético Paranaense': 20,
#  'Goiás': 20,
#  'Avaí FC': 20,
#  'Fortaleza': 20,
#  'Kawasaki Frontale': 29,
#  'Vélez Sarsfield': 28,
#  'Hull City': 30,
#  'Houston Dynamo': 29,
#  'Birmingham City': 30,
#  'Al Wehda': 28,
#  'Nottingham Forest': 30,
#  'CD Tenerife': 30,
#  'Aalborg BK': 24,
#  'Preston North End': 30,
#  'Bristol City': 30,
#  'Lecce': 33,
#  'Gimnasia y Esgrima La Plata': 28,
#  'CD Aves': 25,
#  'Viktoria Plzeň': 25,
#  '1. FC Nürnberg': 30,
#  'Slovenia': 7,
#  'FC Metz': 27,
#  'FC Midtjylland': 27,
#  'Molde FK': 27,
#  'Colo-Colo': 25,
#  'RCD Mallorca': 27,
#  'FC Sion': 27,
#  'Wisła Kraków': 27,
#  'Denizlispor': 23,
#  'Middlesbrough': 30,
#  'Universidad Católica': 28,
#  'Alanyaspor': 29,
#  'Moreirense FC': 26,
#  "Côte d'Ivoire": 7,
#  'Stade Brestois 29': 25,
#  'Chievo Verona': 30,
#  'Boavista FC': 29,
#  'MKE Ankaragücü': 21,
#  'Sydney FC': 21,
#  'Al Ain FC': 27,
#  'Yeni Malatyaspor': 28,
#  'Urawa Red Diamonds': 30,
#  'Querétaro': 28,
#  'Sporting Kansas City': 28,
#  'Málaga CF': 30,
#  '1. FC Heidenheim 1846': 29,
#  'Atlético Tucumán': 27,
#  'Gazişehir Gaziantep F.K.': 30,
#  'Clube Sport Marítimo': 29,
#  'Chapecoense': 20,
#  'Atlético Nacional': 28,
#  'Vitesse': 26,
#  'Australia': 2,
#  'Henan Jianye FC': 27,
#  'Panathinaikos FC': 27,
#  'Blackburn Rovers': 30,
#  'Santa Clara': 27,
#  'Cameroon': 5,
#  'Puebla FC': 27,
#  'U.N.A.M.': 25,
#  'SD Huesca': 26,
#  'Estudiantes de La Plata': 26,
#  'Austria': 1,
#  'KAS Eupen': 27,
#  'LASK Linz': 27,
#  'Sporting de Charleroi': 27,
#  'Daegu FC': 28,
#  'Real Sporting de Gijón': 30,
#  'Derby County': 30,
#  'Rio Ave FC': 27,
#  'South Africa': 12,
#  'Famalicão': 24,
#  'Neuchâtel Xamax': 26,
#  'Benevento': 23,
#  'Cádiz CF': 30,
#  'AIK': 25,
#  'Sheffield Wednesday': 30,
#  'Empoli': 30,
#  'Colorado Rapids': 27,
#  'Os Belenenses': 30,
#  'Unión Magdalena': 28,
#  'Real Oviedo': 30,
#  'Peru': 8,
#  'Antalyaspor': 28,
#  'Dijon FCO': 24,
#  'SV Sandhausen': 30,
#  'Rosario Central': 26,
#  'Reading': 30,
#  'DSC Arminia Bielefeld': 27,
#  'Malmö FF': 24,
#  'Jeonbuk Hyundai Motors': 28,
#  'Frosinone': 25,
#  'FC Tokyo': 30,
#  'Canada': 1,
#  'Çaykur Rizespor': 23,
#  'FCSB (Steaua)': 27,
#  'Defensa y Justicia': 28,
#  'Monarcas Morelia': 28,
#  'Club Atlético Huracán': 25,
#  'Ceará Sporting Club': 20,
#  'Argentinos Juniors': 28,
#  'Al Shabab': 30,
#  'Legia Warszawa': 27,
#  'Shimizu S-Pulse': 30,
#  'Millonarios FC': 7,
#  'Lechia Gdańsk': 27,
#  'Brøndby IF': 27,
#  'Albacete BP': 28,
#  'FC Lorient': 29,
#  'Universitatea Craiova': 27,
#  'Deportivo Cali': 28,
#  'SK Rapid Wien': 25,
#  'Kashima Antlers': 30,
#  'Poland': 1,
#  'Elche CF': 21,
#  'Club Atlético Aldosivi': 26,
#  'Deportes Tolima': 28,
#  'Cúcuta Deportivo': 28,
#  'Club Necaxa': 28,
#  'Piast Gliwice': 27,
#  'Pescara': 30,
#  'Kasimpaşa SK': 27,
#  'Egypt': 17,
#  'Holstein Kiel': 28,
#  'Livorno': 30,
#  'Coquimbo Unido': 26,
#  'UD Las Palmas': 30,
#  'Górnik Zabrze': 27,
#  'FC Twente': 26,
#  'Paris FC': 26,
#  'Racing Club de Lens': 30,
#  'VfL Bochum 1848': 29,
#  'Sunderland': 28,
#  'Aberdeen': 26,
#  'Heart of Midlothian': 28,
#  'Romania': 6,
#  'Crotone': 26,
#  'Iceland': 11,
#  'CFR Cluj': 27,
#  'FK Austria Wien': 27,
#  'UD Almería': 28,
#  'SK Brann': 23,
#  'BK Häcken': 27,
#  'Al Fateh': 28,
#  'CD Everton de Viña del Mar': 26,
#  'FC St. Pauli': 30,
#  'Gamba Osaka': 29,
#  'Yokohama F. Marinos': 27,
#  'Djurgårdens IF': 26,
#  'FC Dallas': 28,
#  'Sagan Tosu': 30,
#  'Al Fayha': 26,
#  'Chile': 1,
#  'Once Caldas': 28,
#  'Atlético Bucaramanga': 28,
#  'FC Cincinnati': 29,
#  'San Jose Earthquakes': 29,
#  'América de Cali': 28,
#  'Perugia': 26,
#  'La Equidad': 28,
#  'SV Darmstadt 98': 30,
#  'FC Zürich': 26,
#  'SC Paderborn 07': 33,
#  'SV Zulte-Waregem': 27,
#  'IFK Norrköping': 26,
#  'FC Viitorul': 27,
#  'Pordenone': 25,
#  'AD Alcorcón': 25,
#  'Sint-Truidense VV': 25,
#  'KV Kortrijk': 26,
#  'Royal Excel Mouscron': 28,
#  'FC Lugano': 27,
#  'Hokkaido Consadole Sapporo': 24,
#  'Spezia': 30,
#  'FC Paços de Ferreira': 28,
#  'Servette FC': 26,
#  'US Salernitana 1919': 30,
#  'Lech Poznań': 27,
#  'ESTAC Troyes': 28,
#  'Fortuna Sittard': 25,
#  'KV Oostende': 26,
#  'VVV-Venlo': 27,
#  'KSV Cercle Brugge': 27,
#  'FC Seoul': 28,
#  'Cerezo Osaka': 30,
#  'Stade Malherbe Caen': 25,
#  'Universidad de Chile': 26,
#  'Kalmar FF': 27,
#  'KV Mechelen': 28,
#  'Deportes Iquique': 26,
#  'US Cremonese': 24,
#  'Bolivia': 21,
#  'Valenciennes FC': 27,
#  'Ulsan Hyundai FC': 28,
#  'Vegalta Sendai': 29,
#  'ADO Den Haag': 25,
#  'CD Palestino': 25,
#  'Cittadella': 26,
#  'Vitória de Setúbal': 30,
#  'FC Nordsjælland': 26,
#  'Charlton Athletic': 29,
#  'Al Raed': 22,
#  'Jagiellonia Białystok': 27,
#  'Odense Boldklub': 22,
#  'FC Thun': 27,
#  'SG Dynamo Dresden': 27,
#  'Hammarby IF': 26,
#  'Central Córdoba': 28,
#  'Queens Park Rangers': 30,
#  ' SSV Jahn Regensburg': 25,
#  'Tiburones Rojos de Veracruz': 27,
#  'Patronato': 28,
#  'Virtus Entella': 30,
#  'SK Sturm Graz': 25,
#  'Kilmarnock': 22,
#  'Extremadura UD': 26,
#  'Willem II': 22,
#  'Gil Vicente FC': 26,
#  'Randers FC': 25,
#  'Ascoli': 29,
#  'Vancouver Whitecaps FC': 7,
#  'Millwall': 30,
#  'Pohang Steelers': 28,
#  'Suwon Samsung Bluewings': 28,
#  'Heracles Almelo': 27,
#  'Al Hazem': 27,
#  'FC Juárez': 26,
#  'SC Heerenveen': 23,
#  'Dinamo Bucureşti': 27,
#  'Gyeongnam FC': 28,
#  'KFC Uerdingen 05': 28,
#  'PEC Zwolle': 27,
#  'Al Faisaly': 20,
#  'Arsenal de Sarandí': 28,
#  'FC Ingolstadt 04': 26,
#  'Wolfsberger AC': 26,
#  'Wigan Athletic': 30,
#  'Júbilo Iwata': 30,
#  'CD Lugo': 29,
#  'SpVgg Greuther Fürth': 29,
#  'FC Emmen': 28,
#  'Cosenza': 22,
#  'AJ Auxerre': 30,
#  'Cracovia': 27,
#  'FC Erzgebirge Aue': 29,
#  'Grenoble Foot 38': 29,
#  'Korona Kielce': 27,
#  'Alianza Petrolera': 28,
#  'CD Universidad de Concepción': 26,
#  'Melbourne City FC': 21,
#  'CD Antofagasta': 24,
#  'Independiente Santa Fe': 28,
#  'Sanfrecce Hiroshima': 24,
#  'Damac FC': 24,
#  'Chamois Niortais Football Club': 27,
#  'Atlético Huila': 25,
#  'CD Numancia': 27,
#  'Luton Town': 30,
#  'Unión La Calera': 24,
#  'Le Havre AC': 26,
#  'AS Nancy Lorraine': 30,
#  'Audax Italiano': 24,
#  'Hibernian': 24,
#  'Barnsley': 30,
#  'Pogoń Szczecin': 27,
#  'Sarpsborg 08 FF': 27,
#  'Kristiansund BK': 21,
#  'FC Luzern': 25,
#  'Unión Española': 27,
#  'IFK Göteborg': 23,
#  'Envigado FC': 26,
#  'Jeju United FC': 28,
#  'Patriotas Boyacá FC': 28,
#  'Peterborough United': 28,
#  'Deportivo Pasto': 28,
#  'Wales': 2,
#  'Clermont Foot 63': 27,
#  'Northern Ireland': 2,
#  'Astra Giurgiu': 27,
#  'Racing Santander': 26,
#  'Pisa': 30,
#  'Newcastle Jets': 22,
#  'Castellammare di Stabia': 28,
#  'Rionegro Águilas': 27,
#  'Vålerenga Fotball': 27,
#  "CD O'Higgins": 27,
#  'AC Ajaccio': 24,
#  'CF Fuenlabrada': 29,
#  'VfL Osnabrück': 30,
#  'Arka Gdynia': 27,
#  'FC Sochaux-Montbéliard': 30,
#  'SpVgg Unterhaching': 28,
#  'Central Coast Mariners': 20,
#  'SV Wehen Wiesbaden': 30,
#  'Fleetwood Town': 28,
#  'Venezia FC': 29,
#  'Karlsruher SC': 28,
#  'Wisła Płock': 27,
#  'Gangwon FC': 28,
#  'IF Elfsborg': 23,
#  'Sangju Sangmu FC': 28,
#  'Zagłębie Lubin': 25,
#  'Abha Club': 21,
#  'Jaguares de Córdoba': 24,
#  'FC Botoşani': 27,
#  'Motherwell': 24,
#  'FC St. Gallen': 27,
#  'Bayern München II': 28,
#  'CD Mirandés': 21,
#  'St. Johnstone FC': 24,
#  'Lillestrøm SK': 23,
#  'Odds BK': 22,
#  'SD Ponferradina': 26,
#  'Doncaster Rovers': 28,
#  'Örebro SK': 27,
#  'Shamrock Rovers': 22,
#  'FSV Zwickau': 23,
#  '1. FC Kaiserslautern': 28,
#  'Portsmouth': 28,
#  'Waasland-Beveren': 26,
#  'Ipswich Town': 28,
#  'Dundalk': 23,
#  'CD Huachipato': 28,
#  'Le Mans FC': 24,
#  'Strømsgodset IF': 27,
#  'Sepsi OSK': 27,
#  'Sparta Rotterdam': 21,
#  'FC Admira Wacker Mödling': 26,
#  'SønderjyskE': 27,
#  'Hallescher FC': 24,
#  'SKN St. Pölten': 24,
#  'MSV Duisburg': 24,
#  'La Berrichonne de Châteauroux': 26,
#  'FC Hansa Rostock': 25,
#  'Incheon United FC': 28,
#  'Shonan Bellmare': 2,
#  'Orlando Pirates': 28,
#  'FK Bodø/Glimt': 27,
#  'Lincoln City': 23,
#  'Brisbane Roar': 24,
#  'Eintracht Braunschweig': 26,
#  'Curicó Unido': 27,
#  'Falkenbergs FF': 24,
#  'Venezuela': 3,
#  '1. FC Magdeburg': 24,
#  'CD Cobresal': 28,
#  'Aarhus GF': 25,
#  'Salford City': 28,
#  'HJK Helsinki': 28,
#  'Oxford United': 28,
#  'Hobro IK': 24,
#  'Esbjerg fB': 24,
#  'Bolton Wanderers': 23,
#  'SV Mattersburg': 25,
#  'Rotherham United': 22,
#  'SCR Altach': 27,
#  'Gaz Metan Mediaş': 27,
#  'Tromsø IL': 27,
#  'WSG Tirol': 25,
#  'IK Sirius': 27,
#  'Shrewsbury': 28,
#  'Oldham Athletic': 28,
#  'Southend United': 28,
#  'Blackpool': 28,
#  'Coventry City': 28,
#  'Adelaide United': 21,
#  'Ranheim Fotball': 23,
#  'SG Sonnenhof Großaspach': 25,
#  'Matsumoto Yamaga': 30,
#  'Burton Albion': 26,
#  'FC Hermannstadt': 27,
#  'TSV 1860 München': 28,
#  'LKS Lodz': 27,
#  'FC Würzburger Kickers': 28,
#  'TSV Hartberg': 26,
#  'Politehnica Iaşi': 27,
#  'Wellington Phoenix': 4,
#  'Milton Keynes Dons': 26,
#  'Stabæk Fotball': 27,
#  'Wycombe Wanderers': 24,
#  'SV Waldhof Mannheim': 27,
#  'AC Horsens': 21,
#  'Scunthorpe United': 28,
#  'RKC Waalwijk': 25,
#  'Oita Trinita': 30,
#  'St. Mirren': 23,
#  'Bristol Rovers': 28,
#  'Rodez Aveyron Football': 26,
#  'SV Meppen': 25,
#  'Viking FK': 25,
#  'Östersunds FK': 27,
#  'FK Haugesund': 27,
#  'Rochdale': 25,
#  'Colchester United': 28,
#  'Trapani': 24,
#  'Stevenage': 28,
#  'Bradford City': 25,
#  'Livingston FC': 28,
#  'FC Chambly Oise': 30,
#  'Mansfield Town': 28,
#  'SC Preußen Münster': 24,
#  'FC Voluntari': 27,
#  'Accrington Stanley': 28,
#  'Al Adalah': 25,
#  'Lyngby BK': 24,
#  'FC Carl Zeiss Jena': 28,
#  'Viktoria Köln': 28,
#  'Tranmere Rovers': 28,
#  'Silkeborg IF': 27,
#  'Gillingham': 27,
#  'Plymouth Argyle': 25,
#  'Chemnitzer FC': 26,
#  'Mjøndalen IF': 22,
#  'Walsall': 26,
#  'Northampton Town': 27,
#  'Hamilton Academical FC': 28,
#  'Grimsby Town': 28,
#  'Exeter City': 28,
#  'Swindon Town': 28,
#  'Raków Częstochowa': 24,
#  'Chindia Târgovişte': 23,
#  'US Orléans Loiret Football': 1,
#  'Forest Green Rovers': 24,
#  'AFC Wimbledon': 28,
#  'Carlisle United': 25,
#  'Morecambe': 27,
#  'Port Vale': 25,
#  'Cheltenham Town': 24,
#  'Academica Clinceni': 26,
#  'Crawley Town': 28,
#  'Ross County FC': 25,
#  'AFC Eskilstuna': 27,
#  'Macclesfield Town': 24,
#  'Cork City': 22,
#  'Newport County': 26,
#  'Crewe Alexandra': 25,
#  'Leyton Orient': 27,
#  'Cambridge United': 24,
#  "St. Patrick's Athletic": 25,
#  'Bohemian FC': 25,
#  'India': 23,
#  'Finland': 1,
#  'Waterford FC': 20,
#  'Derry City': 23,
#  'Bury': 24,
#  'New Zealand': 5,
#  'GIF Sundsvall': 1,
#  'Sligo Rovers': 21,
#  'Finn Harps': 25,
#  'Seongnam FC': 1,
#  'UCD AFC': 21,
#  'Śląsk Wrocław': 1}

# %%
right_list = []
left_list = []
foot_dict = {}
for club in clubs:
    foot = df[df["club"] == club]
    left_footer = foot[foot['preferred_foot'] == "Left"]
    right_footer = foot[foot['preferred_foot'] == "Right"]
    foot_dict['left_foot_players'] = left_footer
    foot_dict['right_foot_players'] = right_footer
    left_list.append(foot_dict['left_foot_players'])
    right_list.append(foot_dict['right_foot_players'])
right_list[11]
# Out:
#        sofifa_id                                         player_url  \
# 20        188545  https://sofifa.com/player/188545/robert-lewand...
# 31        167495  https://sofifa.com/player/167495/manuel-neuer/...
# 52        189509  https://sofifa.com/player/189509/thiago-alcant...
# 61        212622  https://sofifa.com/player/212622/joshua-kimmic...
# 68        189242  https://sofifa.com/player/189242/philippe-cout...
# 70        189596  https://sofifa.com/player/189596/thomas-muller...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# 117       209658  https://sofifa.com/player/209658/leon-goretzka...
# 119       213345  https://sofifa.com/player/213345/kingsley-coma...
# 120       206113  https://sofifa.com/player/206113/serge-gnabry/...
# 136       177610  https://sofifa.com/player/177610/javier-martin...
# 140       181458  https://sofifa.com/player/181458/ivan-perisic/...
# 143       183907  https://sofifa.com/player/183907/jerome-boaten...
# 166       219683  https://sofifa.com/player/219683/corentin-toli...
# 597       226851  https://sofifa.com/player/226851/benjamin-pava...
# 697       186569  https://sofifa.com/player/186569/sven-ulreich/...
# 1642      230767  https://sofifa.com/player/230767/renato-junior...
# 7694      239981  https://sofifa.com/player/239981/jann-fiete-ar...
# 12225     241859  https://sofifa.com/player/241859/ron-thorben-h...
#
#            short_name                       long_name  age         dob  \
# 20     R. Lewandowski              Robert Lewandowski   30  1988-08-21
# 31           M. Neuer                    Manuel Neuer   33  1986-03-27
# 52             Thiago  Thiago Alcântara do Nascimento   28  1991-04-11
# 61         J. Kimmich                  Joshua Kimmich   24  1995-02-08
# 68           Coutinho       Philippe Coutinho Correia   27  1992-06-12
# 70          T. Müller                   Thomas Müller   29  1989-09-13
# 77            N. Süle                     Niklas Süle   23  1995-09-03
# 117       L. Goretzka                   Leon Goretzka   24  1995-02-06
# 119          K. Coman                  Kingsley Coman   23  1996-06-13
# 120         S. Gnabry                    Serge Gnabry   23  1995-07-14
# 136     Javi Martínez         Javier Martínez Aginaga   30  1988-09-02
# 140        I. Perišić                    Ivan Perišić   30  1989-02-02
# 143        J. Boateng                  Jérôme Boateng   30  1988-09-03
# 166        C. Tolisso                Corentin Tolisso   24  1994-08-03
# 597         B. Pavard                 Benjamin Pavard   23  1996-03-28
# 697        S. Ulreich                    Sven Ulreich   30  1988-08-03
# 1642   Renato Sanches       Renato Júnior Luz Sanches   21  1997-08-18
# 7694           J. Arp                  Jann-Fiete Arp   19  2000-01-06
# 12225     R. Hoffmann            Ron-Thorben Hoffmann   20  1999-04-04
#
#        height_cm  weight_kg nationality               club  ...   ldm   cdm  \
# 20           184         80      Poland  FC Bayern München  ...  62+3  62+3
# 31           193         92     Germany  FC Bayern München  ...   NaN   NaN
# 52           174         70       Spain  FC Bayern München  ...  78+3  78+3
# 61           176         73     Germany  FC Bayern München  ...  82+3  82+3
# 68           172         68      Brazil  FC Bayern München  ...  68+3  68+3
# 70           186         75     Germany  FC Bayern München  ...  68+3  68+3
# 77           195         97     Germany  FC Bayern München  ...  77+2  77+2
# 117          189         79     Germany  FC Bayern München  ...  79+3  79+3
# 119          179         75      France  FC Bayern München  ...  54+2  54+2
# 120          175         75     Germany  FC Bayern München  ...  62+2  62+2
# 136          192         86       Spain  FC Bayern München  ...  80+3  80+3
# 140          186         80     Croatia  FC Bayern München  ...  71+3  71+3
# 143          192         90     Germany  FC Bayern München  ...  79+3  79+3
# 166          181         81      France  FC Bayern München  ...  80+2  80+2
# 597          186         76      France  FC Bayern München  ...  78+2  78+2
# 697          192         87     Germany  FC Bayern München  ...   NaN   NaN
# 1642         176         70    Portugal  FC Bayern München  ...  73+3  73+3
# 7694         184         78     Germany  FC Bayern München  ...  39+2  39+2
# 12225        192         84     Germany  FC Bayern München  ...   NaN   NaN
#
#         rdm   rwb    lb   lcb    cb   rcb    rb  \
# 20     62+3  61+3  58+3  57+3  57+3  57+3  58+3
# 31      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 52     78+3  78+3  75+3  69+3  69+3  69+3  75+3
# 61     82+3  83+3  81+3  78+3  78+3  78+3  81+3
# 68     68+3  70+3  66+3  58+3  58+3  58+3  66+3
# 70     68+3  69+3  67+3  62+3  62+3  62+3  67+3
# 77     77+2  71+2  75+2  83+2  83+2  83+2  75+2
# 117    79+3  79+3  78+3  76+3  76+3  76+3  78+3
# 119    54+2  59+2  55+2  43+2  43+2  43+2  55+2
# 120    62+2  66+2  62+2  53+2  53+2  53+2  62+2
# 136    80+3  74+3  76+3  84+3  84+3  84+3  76+3
# 140    71+3  74+3  72+3  67+3  67+3  67+3  72+3
# 143    79+3  75+3  77+3  82+3  82+3  82+3  77+3
# 166    80+2  76+2  76+2  77+2  77+2  77+2  76+2
# 597    78+2  76+2  77+2  78+2  78+2  78+2  77+2
# 697     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1642   73+3  72+3  71+3  72+3  72+3  72+3  71+3
# 7694   39+2  44+2  41+2  36+2  36+2  36+2  41+2
# 12225   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                                                image_url
# 20     https://sofifa.com/player/188545/robert-lewand...
# 31        https://sofifa.com/player/167495/manuel-neuer/
# 52     https://sofifa.com/player/189509/thiago-alcant...
# 61      https://sofifa.com/player/212622/joshua-kimmich/
# 68     https://sofifa.com/player/189242/philippe-cout...
# 70       https://sofifa.com/player/189596/thomas-muller/
# 77         https://sofifa.com/player/212190/niklas-sule/
# 117      https://sofifa.com/player/209658/leon-goretzka/
# 119     https://sofifa.com/player/213345/kingsley-coman/
# 120       https://sofifa.com/player/206113/serge-gnabry/
# 136    https://sofifa.com/player/177610/javier-martin...
# 140       https://sofifa.com/player/181458/ivan-perisic/
# 143     https://sofifa.com/player/183907/jerome-boateng/
# 166    https://sofifa.com/player/219683/corentin-toli...
# 597    https://sofifa.com/player/226851/benjamin-pavard/
# 697       https://sofifa.com/player/186569/sven-ulreich/
# 1642   https://sofifa.com/player/230767/renato-junior...
# 7694    https://sofifa.com/player/239981/jann-fiete-arp/
# 12225  https://sofifa.com/player/241859/ron-thorben-h...
#
# [19 rows x 105 columns]

# %%
# Plotting functions for easier use and reusability

def barhplot(x, y, xlabel,ylabel, title):
    plt.figure(figsize=  (15, 8))
    plt.barh(x, y, align = 'center')
    plt.xticks(rotation=90)
    plt.gca().invert_yaxis()
    plt.xlabel(xlabel, fontsize = 16)
    plt.ylabel(ylabel, fontsize = 16)
    plt.title(title, fontsize = 16)
    plt.show();

def barplot(x, y, xlabel,ylabel,title,ticks):
    plt.figure(figsize=  (15, 8))
    plt.bar(x, y, align = 'center')
    plt.xlabel(xlabel, fontsize = 16)
    plt.ylabel(ylabel, fontsize = 16)
    plt.title(title, fontsize = 16)
    plt.xticks(rotation=90)
    plt.show();

def lineplot(value, xlabel, ylabel, title):
    plt.figure(figsize=  (16, 8))
    plt.plot(value)
    plt.xlabel(xlabel, fontsize = 16)
    plt.ylabel(ylabel, fontsize = 16)
    plt.title(title, fontsize = 20)
    plt.show();

def sortby(column):
    data_1 = data.sort_values(by = column, ascending = False)
    return data

# %%
# Top 10 bayern munich Right footer ratings
bayern_munich_right = right_list[11][['overall','long_name']][:10]
bayern_munich_left = left_list[11][['overall','long_name']][:10]

# %%
# plotting the right footer ratings

# extracting the names and the ratings from the dataframe
# Names
names_right = bayern_munich_right['long_name']
names_left = bayern_munich_left['long_name']

# Overall Ratings
rating_right = bayern_munich_right['overall']
rating_left = bayern_munich_left['overall']


# Changing the names into a list format
names_right = list(names_right)
names_left = list(names_left)


# Horizontal bar chart 
barhplot(names_left,rating_left,'Overall Ratings','Player Names','Player Ratings[Left and Right footers]')
barhplot(names_right,rating_right,'Overall Ratings','Player Names','Player Ratings[Left and Right footers]')

plt.show()

# %%
# # Creating a images folder
# folder = "players_images"
# if not os.path.exists(folder):
#     os.makedirs(folder)

# # Creating a function to extract the image from the image_url column
# def extract(url):
#     url = requests.get(url)
#     soup = bs(url.content,'lxml')
#     img = soup.find('div', attrs={'class':'bp3-card player'}).find('img')['data-srcset'].split(" ")[2]
#     url = requests.get(img)
#     name = soup.find('div', attrs={'class':'info'}).find('h1').get_text()
#     image = Image.open(BytesIO(url.content))
#     image.save(folder + "/" + "_" + name + '.' + 'png')

# Plotting the graph of the Top_20 players and their ratings from each club using barplot 
# #Running a for loop through the image list
# image_list = list(df['image_url'])
# for image in image_list:
#     extract(image)

# %% [markdown]
# #### TOP_20 BEST PLAYER IN ALL CLUBS BASED ON RATINGS

# %%
# Best player in all clubs

# Initializing the dictionary
club_best_players_dic = {}
club_dic_keys = list(club_dic.keys())
club_dic_values = list(club_dic.values())
club_dic_item = list(club_dic.items())

#Gathering best players from each clubs
for key in club_dic_keys:
    best_player_rating = club_dic[key]['overall'].max()
    best_player = club_dic[key][club_dic[key]['overall'] == best_player_rating]['long_name']
    club_best_players_dic[key] = [best_player,best_player_rating]

# Player - rating dictionary
player_rating_dic = {}
player_name_list = []
player_rating_list = []
for key in club_best_players_dic:
    player_name = club_best_players_dic[key][0]
    player_name_list.append(str(player_name))
    player_rating = club_best_players_dic[key][1]
    player_rating_list.append(player_rating)

    
# Extracting and listing the player names into a new list
new_player_name_list = []
for player in player_name_list:
    player = re.findall(r'[a-zA-Z\D]+(?=\n)',player)
    new_player_name_list.append(player[0])

# Using the zip function and changing the list into a dictionary
player_ratings = dict(zip(new_player_name_list,player_rating_list))


# Sorting the dicionary by rating values
dictionary_keys = list(player_ratings.keys())
club_top_20_best_players = {dictionary_keys[i]: sorted(
    player_ratings.values(),reverse = True)[i] for i in range(len(dictionary_keys)) if i <= 20}
club_top_20_best_players
# Out:
# {'    Lionel Andrés Messi Cuccittini': 94,
#  '    Cristiano Ronaldo dos Santos Aveiro': 93,
#  '    Neymar da Silva Santos Junior': 92,
#  '    Jan Oblak': 91,
#  '    Eden Hazard': 91,
#  '    Kevin De Bruyne': 91,
#  '         Virgil van Dijk': 90,
#  '    Kalidou Koulibaly': 89,
#  '    Harry Kane': 89,
#  '    David De Gea Quintana': 89,
#  "    N'Golo Kanté": 89,
#  '    Robert Lewandowski': 89,
#  '    Samir Handanovič': 88,
#  '    Marco Reus': 88,
#  '    Pierre-Emerick Aubameyang': 88,
#  '    Daniel Parejo Muñoz': 86,
#  '    Ciro Immobile': 86,
#  '    Gianluigi Donnarumma': 85,
#  '    Bruno Miguel Borges Fernandes': 85,
#  '    Anthony Lopes': 85,
#  '    Péter Gulácsi': 85}

# %% [markdown]
# #### TOP_20 BEST PLAYER IN EACH CLUB WITH RESPECT TO RATINGS[Visulaization]

# %%
# Plotting the graph of the Top_20 players and their ratings from each club using barplot 
barplot(club_top_20_best_players.keys(),club_top_20_best_players.values(),'Player Names','Player Ratings','Top_20 Best players in all clubs',club_top_20_best_players.values())

# %%
# Overall best player by ratings using

# %% [markdown]
# #### TOP_20 BEST PLAYER IN ALL NATIONS BASED ON RATINGS

# %%
# Best player in all clubs

# Initializing the dictionary
nation_best_players_dic = {}
nation_dic_keys = list(nation_dic.keys())
nation_dic_values = list(nation_dic.values())
nation_dic_item = list(nation_dic.items())

#Gathering best players from each clubs
for key in nation_dic_keys:
    best_player_rating = nation_dic[key]['overall'].max()
    best_player = nation_dic[key][nation_dic[key]['overall'] == best_player_rating]['long_name']
    nation_best_players_dic[key] = [best_player,best_player_rating]

# Player - rating dictionary
nation_player_name_list = []
nation_player_rating_list = []
for key in nation_best_players_dic:
    nation_player_name = nation_best_players_dic[key][0]
    nation_player_name_list.append(str(nation_player_name))
    nation_player_rating = nation_best_players_dic[key][1]
    nation_player_rating_list.append(nation_player_rating)
    
# Extracting and listing the player names into a new list
new_nation_player_name_list = []
for player in nation_player_name_list:
    player = re.findall(r'[a-zA-Z\D]+(?=\n)',player)
    new_nation_player_name_list.append(player[0])

# Using the zip function and changing the list into a dictionary
nation_player_ratings = dict(zip(new_nation_player_name_list,nation_player_rating_list))


# Sorting the dicionary by rating values
dictionary_keys = list(nation_player_ratings.keys())
nation_top_20_best_players = {dictionary_keys[i]: sorted(
    nation_player_ratings.values(),reverse = True)[i] for i in range(len(dictionary_keys)) if i <= 20}
nation_top_20_best_players
# Out:
# {'    Lionel Andrés Messi Cuccittini': 94,
#  '    Cristiano Ronaldo dos Santos Aveiro': 93,
#  '    Neymar da Silva Santos Junior': 92,
#  '    Jan Oblak': 91,
#  '        Eden Hazard': 91,
#  '    Marc-André ter Stegen': 90,
#  '    Virgil van Dijk': 90,
#  '    Luka Modrić': 90,
#  '    Mohamed  Salah Ghaly': 90,
#  '        Kylian Mbappé': 89,
#  '    Kalidou Koulibaly': 89,
#  '    Harry Kane': 89,
#  '       David De Gea Quintana': 89,
#  '    Giorgio Chiellini': 89,
#  '    Luis Alberto Suárez Díaz': 89,
#  '    Robert Lewandowski': 89,
#  '    Christian  Dannemann Eriksen': 88,
#  '    Pierre-Emerick Aubameyang': 88,
#  '    손흥민 孙兴慜': 87,
#  '    Keylor Navas': 87,
#  '    Milan Škriniar': 86}

# %% [markdown]
# #### TOP_20 BEST PLAYER IN ALL NATIONS BASED ON RATINGS[Visualization]

# %%
# Plotting the graph of the Top_20 players and their ratings from each club using barplot from the originally written graphfunctions
barplot(nation_top_20_best_players.keys(),nation_top_20_best_players.values(),'Player Names','Player Ratings','Top_20 Best players in all nations',nation_top_20_best_players.values())
